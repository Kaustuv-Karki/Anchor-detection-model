# %%
import tensorflow as tf

# %%
# !pip install ultralytics -q

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('./runs/detect/train/weights/best.pt')  # build a new model from YAML


# Train the model
model.train(data='config.yaml', epochs=50)
# Out:
# Ultralytics YOLOv8.0.131  Python-3.10.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...
